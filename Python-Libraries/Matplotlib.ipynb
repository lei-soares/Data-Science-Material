# %% [markdown]
# # Matplotlib
#
# Matplotlib is a Python 2D plotting library which produces
# publication-quality figures in a variety of hardcopy formats
# and interactive environments across
# platforms.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Prepare The Data

# %%
# 1D data
x = np.linspace(0, 10, 100)
y = np.cos(x) 
z = np.sin(x)

# %%
# 2D Data or Images

data = 2 * np.random.random((10, 10))
data2 = 3 * np.random.random((10, 10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2

# %%
df = pd.DataFrame(V)
df
# Out:
#            0          1          2          3          4          5   \
# 0  -11.000000 -10.939394 -10.878788 -10.818182 -10.757576 -10.696970
# 1  -10.640037 -10.579431 -10.518825 -10.458219 -10.397612 -10.337006
# 2  -10.287420 -10.226814 -10.166208 -10.105601 -10.044995  -9.984389
# 3   -9.942149  -9.881543  -9.820937  -9.760331  -9.699725  -9.639118
# 4   -9.604224  -9.543618  -9.483012  -9.422406  -9.361800  -9.301194
# ..        ...        ...        ...        ...        ...        ...
# 95  -9.604224  -9.543618  -9.483012  -9.422406  -9.361800  -9.301194
# 96  -9.942149  -9.881543  -9.820937  -9.760331  -9.699725  -9.639118
# 97 -10.287420 -10.226814 -10.166208 -10.105601 -10.044995  -9.984389
# 98 -10.640037 -10.579431 -10.518825 -10.458219 -10.397612 -10.337006
# 99 -11.000000 -10.939394 -10.878788 -10.818182 -10.757576 -10.696970
#
#            6          7          8          9   ...        90        91  \
# ...

# %% [markdown]
# # Create Plot

# %% [markdown]
# ## Figure

# %%
fig = plt.figure()

# %%
fig2 = plt.figure(figsize=plt.figaspect(.2))
plt.plot(x,y)

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y)

# %% [markdown]
# ## Axes
# All plotting is done with respect to an Axes. In most cases, a
# subplot will fit your needs. A subplot is an axes on a grid system.

# %%
fig

# %%
# fig.add_axes()
ax1 = fig.add_subplot(221) # row-col-num

# %%
ax3 = fig.add_subplot(212)

# %%
fig3, axes = plt.subplots(nrows=2,ncols=2)

# %%
fig4, axes2 = plt.subplots(ncols=3)

# %% [markdown]
# # Plotting Routines
# ## 1D Data

# %%
lines = plt.plot(x,y)                # Draw points with lines or markers connecting them

# %%
plt.scatter(x,y)                     # Draw unconnected points, scaled or colored

# %%
plt.fill(x,y,color='blue')           # Draw filled polygons 
plt.fill_between(x,y,color='yellow') # Fill between y-values and 0

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)


axes[0,0].bar([1,2,3],[3,4,5])      # Plot vertical rectangles (constant width)       
axes[1,0].barh([0.5,1,2.5],[0,1,2]) # Plot horiontal rectangles (constant height)
axes[1,1].axhline(0.45)             # Draw a horizontal line across axes   
axes[0,1].axvline(0.65)             # Draw a vertical line across axes

plt.tight_layout()

# %% [markdown]
# ## Vector Fields

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0,1].arrow(0,0,0.5,0.5)    # Add an arrow to the axes
axes[0,1].streamplot(X,Y,U,V)   # Plot 2D vector fields

axes[1,1].quiver(y,z)           # Plot a 2D field of arrows

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,3))

axes[0].arrow(0,0,0.5,0.5)    # Add an arrow to the axes
axes[0].streamplot(X,Y,U,V)   # Plot 2D vector fields

axes[1].quiver(y,z)           # Plot a 2D field of arrows

# %% [markdown]
# ## Data Distributions

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8,3))

axes[0,0].hist(x)           # Plot a histogram
axes[0,1].boxplot(y)        # Make a box and whisker plot
axes[1,0].violinplot(z)     # Make a violin plot# 
axes[1,1].scatter(x,z)     # Make a violin plot#

# %% [markdown]
# ## 2D Data or Images

# %%
fig, ax = plt.subplots() 
im = ax.imshow(V,     #Colormapped or RGB arrays                       
           #cmap='gist_earth',
           interpolation='nearest',
           vmin=-2,
           vmax=2)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2) 
im = ax[1].imshow(V,     #Colormapped or RGB arrays                       
           #cmap='gist_earth',
           interpolation='nearest',
           vmin=-2,
           vmax=2)

im = ax[0].imshow(U,     #Colormapped or RGB arrays                       
           #cmap='gist_earth',
           interpolation='nearest',
           vmin=-2,
           vmax=2)

# %%
axes2[0].pcolor(data2)       # Pseudocolor plot of 2D array
axes2[0].pcolormesh(data)    # Pseudocolor plot of 2D array
CS = plt.contour(Y,X,U)      # Plot contours
axes2[1].contourf(X)         # Plot filled contours
#axes2[2]= axes.clabel(CS)      # Label a contour plot

# %% [markdown]
# #   Customize Plot
# ## Workflow > Plot Anatomy

# %%
x = [1,2,3,4]            # data
y = [10,20,25,30]        # data

fig = plt.figure()             # figure
ax = fig.add_subplot(111)      # allowing adding features
ax.plot(x, y, color='blue', linewidth=3)    # sub 1
ax.scatter([2,4,6],                              # sub 2
               [5,15,25], 
               color='red', 
               marker='^')
ax.set_xlim(1, 6.5)            # axes limmit   .set_ylimit(start, end)
# plt.savefig('foo.png')       # save
plt.show()                     # show chart

# %% [markdown]
# ## Customize Plot
# ### Colors, Color Bars & Color Maps

# %%
fig = plt.figure()
ax = fig.add_subplot(111) 
#plt.plot(x, x)#, x, x**2, x, x**3)
ax.plot(x, y, alpha = 0.4)
ax.plot(x, y, c='k')
fig.colorbar(im, orientation='horizontal') 
im = ax.imshow(V, cmap='seismic')
# Out:
# C:\Users\pantu\AppData\Local\Temp\ipykernel_24992\3986920056.py:6: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 1 Axes> which fig.colorbar is called on.
#   fig.colorbar(im, orientation='horizontal')

# %% [markdown]
# ### Markers

# %%
fig, ax = plt.subplots()
ax.scatter(x,y,marker=".")
ax.plot(x,y,marker="o")

# %% [markdown]
# ### Styles

# %%
x = np.array(x)
y = np.array(y)


plt.plot(x,y,linewidth=4.0)
plt.plot(x,y,ls='solid') 
plt.plot(x,y,ls='--')
plt.plot(x, y, '--', x**2, y**2, '-.')
plt.setp(lines,color='r',linewidth=4.0)
# Out:
# [None, None]

# %%
plt.plot(x, y, '-o', x**2, y**2, '-.')

# %%
plt.scatter(x,y)
ax.text(2, 
        20, 
        'Example Graph', 
        style='italic')

ax.annotate("Sine",
            xy=(8, 0), 
            xycoords='data',
            xytext=(10.5, 0), 
            textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),)
plt.show()

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
###   Limits & Autoscaling

fig, ax = plt.subplots()
ax.scatter(x,y,marker=".")



ax.margins(x=0.0,y=0.1)                      # Add padding to a plot
ax.axis('equal')                             # Set the aspect ratio of the plot to 1
ax.set(xlim=[0,10.5],ylim=[-1.5,1.5])        #            Set limits for x-and y-axis
ax.set_xlim(0,10.5)                          # Set limits for x-axis
# Out:
# (0.0, 10.5)

# %%
#### Legends
ax.set(title='An Example Axes',              # Set a title and x-and y-axis labels 
           ylabel='Y-Axis',  
           xlabel='X-Axis')
ax.legend(loc='best')                        # No overlapping plot elements
####    Ticks
ax.xaxis.set(ticks=range(1,5),               # Manually set x-ticks
                 ticklabels=[3,100,-12,"foo"])
ax.tick_params(axis='y',                     # Make y-ticks longer and go in and out
                   direction='inout', 
                   length=10)


####   Subplot Spacing
fig3.subplots_adjust(wspace=0.5,              # Adjust the spacing between subplots
                        hspace=0.3,                   
                        left=0.125, 
                        right=0.9, 
                        top=0.9, 
                        bottom=0.1) 
fig.tight_layout()                            # Fit subplot(s) in to the figure area



####   Axis Spines
ax1.spines['top'].set_visible(False)          # Make the top axis line for a plot invisible
ax1.spines['bottom'].set_position(('outward',10)) # Move the bottom axis line outward
# Out:
# C:\Users\pantu\AppData\Local\Temp\ipykernel_24992\2930139411.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='best')                        # No overlapping plot elements

# %% [markdown]
# #   Save Plot

# %% [markdown]
# #  Show Plot

# %% [markdown]
# # Close & Clear

# %%
plt.cla()               #Clear an axis
plt.clf()               #Clear the entire figure
plt.close()             #Close a window

# %% [markdown]
# # Stylish Plot - Designed Plot

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
# Out:
# <Axes: >
